# %% [markdown]
# # CIA UFO Collection - OCR
#
# ## Author: Vince Egalla
#
# ## Source: The Black Vault
# https://www.theblackvault.com/documentarchive/ufos-the-central-intelligence-agency-cia-collection/

# %%
## Dependencies

from PIL import Image
from os import listdir
from os.path import isfile, join
import pytesseract
import argparse
import cv2
import os

# %% [markdown]
# #### Initial Testing

# %%
## Fix Tesseract interaction
# https://stackoverflow.com/questions/50951955/pytesseract-tesseractnotfound-error-tesseract-is-not-installed-or-its-not-i
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
# load the example image and convert it to grayscale
image = cv2.imread("_data\CIAUFOCD-FULL-UNTOUCHED\C05515622.tif")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

## Thresh preprocess
#gray = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
## make a check to see if median blurring should be done to remove noise

## Blur preprocess
gray = cv2.medianBlur(gray, 3)

# write the grayscale image to disk as a temporary file so we can
# apply OCR to it
filename = "{}.png".format(os.getpid())
cv2.imwrite(filename, gray)
# Out:
# True

# %%
text = pytesseract.image_to_string(Image.open(filename))
os.remove(filename)
print(text)
# show the output images
#cv2.imshow("Image", image)
#cv2.imshow("Output", gray)
#cv2.waitKey(0)
# Out:
#
#
# at > omnes
#
# C00015235
#
# ewe
#
#
#
#
#
# 26 APRIL 1976 1000 1 hea 2G 1 3 $2"16
#
# ron +o, mnnieneey
#
# SUBJECT 1 DCD CASE a -. UFO RESEARCH ey
# REFERENCES? ay a ee,» 22 APRIL 1976
# ) Ey ~ - .
#
# te PR MALS Une eas - od
#
# 1. PER THE REQUEST IN REFERENCE (B) ° WE ATTEMPTED TO OBTAIN
#
# ANALYTICAL GUIDANCE ON THE Uo (ED 52227.
# 2, WE CONTACTED THE ippset on TO SFE IF HE
#
# KNEW OF ANY OFFICIAL UFO "PROGRAM AND ALSO TO ATTEMPT TO ANSWER
#
# SOME OF THE QUESTIONS POSED BY Ga? > 7 EXHIBITED INTEREST
# ry QR wurce was HANDCARRIED TO BIS ‘OFFICE. AFTER A SHORT
# EXAMINATION OF ITS CONTENTS DR QHD xovisen us raat HE wourp
# PERSONALLY LOOK INTO THE MATTER AND GET BACK TO US. AS WE DISCUSSED
#
# IN REFERENCE {A) DR GHEE «s SINCE CONTACTED US AND RELAYED THE
#
# FOLLOWING INFORMATION. - Les
#
# - aes ‘a,
#
# 3. IT WOULD APPEAR TO BE BEST IF YOU ADVISED QED tear az
#
#
#
# arn. Ar ye . wt ts
# aa . oe + ie -: a> Tare 7; ms Soe
# wat ad we 2 + Sous at
#
#
#
# ...

# %% [markdown]
# #### Get list of image files in data repository
# Image extension: .tif
#
# Data repository also includes OCR text output created by ???

# %%
datapath = "_data/CIAUFOCD-FULL-UNTOUCHED"

onlyfiles = [f for f in listdir(datapath) if isfile(join(datapath, f))]

imagefiles = [f for f in onlyfiles if ".tif" in f]

imagefiles
# Out:
# ['C05515622.tif',
#  'C05515624.tif',
#  'C05515625.tif',
#  'C05515646.tif',
#  'C05515647.tif',
#  'C05515648.tif',
#  'C05515649.tif',
#  'C05515650.tif',
#  'C05515651.tif',
#  'C05515652.tif',
#  'C05515653.tif',
#  'C05515654.tif',
#  'C05515655.tif',
#  'C05515656.tif',
#  'C05515657.tif',
#  'C05515658.tif',
#  'C05515659.tif',
#  'C05515660.tif',
#  'C05515661.tif',
#  'C05515662.tif',
#  'C05515663.tif',
#  'C05515664.tif',
#  'C05515665.tif',
#  'C05515686.tif',
#  'C05515687.tif',
#  'C05515688.tif',
#  'C05515689.tif',
#  'C05515691.tif',
#  'C05515692.tif',
#  'C05515694.tif',
#  'C05515695.tif',
#  'C05515698.tif',
#  'C05515699.tif',
#  'C05515701.tif',
#  'C05515702.tif',
#  'C05515703.tif',
#  'C05515704.tif',
#  'C05515705.tif',
#  'C05515706.tif',
#  'C05515707.tif',
#  'C05515708.tif',
#  'C05515709.tif',
#  'C05515711.tif',
#  'C05515712.tif',
#  'C05515713.tif',
#  'C05515714.tif',
#  'C05515715.tif',
#  'C05515716.tif',
#  'C05515718.tif',
#  'C05515719.tif',
# ...

# %% [markdown]
# #### Define OCR function

# %%
def OCR(i, preprocess):
    # load the example image and convert it to grayscale
    filename = i.replace('.tif','')
    image = cv2.imread("_data/CIAUFOCD-FULL-UNTOUCHED/" + i)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    if preprocess = "thresh":
        gray = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
    ## make a check to see if median blurring should be done to remove noise

    elif preprocess = "blur":
        gray = cv2.medianBlur(gray, 3)
    
    ## Image to Text
    text = pytesseract.image_to_string(gray)
    
    f = open("_output/OCR/" + filename + ".txt", "w")
    f.writelines(text)
    f.close

# %% [markdown]
# #### Function Test

# %%
OCR("C05530814.tif", "blur")

# %% [markdown]
# #### Function Loop

# %%
# for i in imagefiles:
#     OCR(i, "blur")
